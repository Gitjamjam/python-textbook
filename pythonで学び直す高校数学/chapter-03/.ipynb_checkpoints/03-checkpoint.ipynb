# %% [markdown]
# # リスト3-2

# %%
# %matplotlib inline 
#jupyter の命令セルと同じセルにグラフを描画

import matplotlib.pyplot as plt

#データ
x = [1,2,3,4,5,6,7]
y = [64.3, 63.8, 63.6, 64.0, 63.5, 63.2, 63.1]

#グラフを描画
plt.plot(x,y, marker='o')    #折れ線を描画
plt.grid(color='0.8')    #グリッド表示
plt.show()    #画面に表示

# %% [markdown]
# # リスト3-2
# ## y=3x - 24 のグラフ

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

#データ
x = list(range(1,11))  #xの値 1~10
y = []
for i in range(10):
    y.append(3 * x[i] - 24)  #y = 3x - 24

#グラフ
plt.plot(x, y)
plt.grid(color='0.8')
plt.show()

# %% [markdown]
# # リスト 3-3
# ## y = 3x のグラフ

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

#データ
x = np.arange(-1.0, 1.01, 0.01)  # -1 から 1 までの値が 0. 1 間隔で代入
y = 3 * x

#グラフを描画
plt.plot(x, y)
plt.grid(color='0.8')
plt.show()

# %% [markdown]
# # リスト 3-4
# ## 連立方程式を解く

# %%
from sympy import Symbol, solve

#式を定義
a = Symbol('a')
b = Symbol('b')
ex1 = a + b - 1
ex2 = 5*a + b - 3

#連立方程式を解く
print(solve((ex1, ex2)))
# Out:
# {a: 1/2, b: 1/2}

# %% [markdown]
# # リスト 3-5
# ## y = 1/2x + 1/2 と y = -2x + 7

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-1, 6)  # x軸の値
y = 1/2 * x + 1/2  # 直線1
y2 = -2 * x + 7  # 直線1に直交する直線

# グラフを描画
plt.plot(x, y)
plt.plot(x, y2)
plt.axis('equal')
plt.grid(color='0.8')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # 3.32｜直線の交点
# - 平面上に2本の直線を描画したとき、その2直線が平行でない限り必ずどこか1点で交わります。
# - このときの交点は、2つの直線の式を同時に満たす点、つまり、連立方程式の解になります。

# %%
from sympy import Symbol, solve
x = Symbol('x')
y = Symbol('y')
ex1 = -3/2*x + 6 - y  # 直線1の式を定義
ex2 = 1/2*x + 2 - y  # 直線2の式を定義
print(solve((ex1, ex2)))
# Out:
# {x: 2.00000000000000, y: 3.00000000000000}
